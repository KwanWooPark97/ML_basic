# %%
import numpy as np
import numpy.random as rnd
np.random.seed(42)
m = 200
X = 6 * np.random.rand(m, 1) - 3
y = 0.5 * X**2 + X + 2 + np.random.randn(m,1)

# %%
print(y)
# Out:
# [[ 0.85053926]
#  [ 8.59312048]
#  [ 4.65381753]
#  [ 2.05280242]
#  [ 3.93170352]
#  [ 2.5399159 ]
#  [ 1.67241986]
#  [ 7.26713994]
#  [ 1.81604482]
#  [ 4.81481563]
#  [ 4.41920863]
#  [ 7.97345164]
#  [ 6.94735794]
#  [ 2.17629376]
#  [ 2.73524629]
#  [ 3.80140872]
#  [ 1.26984513]
#  [ 1.40583428]
#  [ 0.78552233]
#  [ 0.71609945]
#  [ 2.81921492]
#  [ 2.51747932]
#  [ 1.80722794]
#  [ 2.34681913]
#  [ 1.78415903]
#  [ 6.62844577]
#  [ 1.55691093]
#  [ 4.80922294]
#  [ 3.33388291]
#  [ 2.12427503]
#  [ 1.78256273]
#  [ 2.45959551]
#  [ 2.57208887]
#  [ 9.03428178]
#  [ 9.16966725]
#  [ 5.48951581]
#  [ 0.66805292]
#  [ 0.98480456]
#  [ 3.26983575]
#  [ 2.56178479]
#  [ 2.51771488]
#  [ 0.7257414 ]
#  [ 3.28180494]
#  [ 7.85701724]
#  [ 0.7161902 ]
#  [ 3.60430168]
#  [ 1.56662411]
#  [ 0.98468689]
#  [ 2.67732234]
#  [ 2.45761212]
#  [ 9.86973402]
#  [ 6.06716426]
#  [ 6.73619203]
#  [ 6.23713452]
#  [ 3.27495445]
#  [ 8.24863302]
#  [ 3.09409427]
#  [ 5.69230422]
# ...
