# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

def sigmoid(x):
    return 1/(1+np.exp(-x))

degree = 2 # features of x
m = 1000 #학습 데이터 개수
half_m = int(m/2)

x1_data = np.array((np.random.normal(0.5, 0.3, half_m), np.random.normal(-0.5, 0.3, half_m)))
x1_data = np.resize(x1_data, m)

x2_data = np.array((np.random.normal(-0.5, 0.3, half_m), np.random.normal(0.5, 0.3, half_m)))
x2_data = np.resize(x2_data, m)

y_data = np.array((np.ones(half_m), np.zeros(half_m)))
y_data = np.resize(y_data, m)


plt.plot(x1_data[0:half_m], x2_data[0:half_m], 'r.',label = '1')
plt.plot(x1_data[half_m:], x2_data[half_m:], 'b.',label = '0')
plt.legend()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ${\partial J(W) \over \partial W_j} = \frac{1}{m} \sum^{m}_{i=1}(H(\hat{y}^i)-y^i)x^i_j$

# %%
num_epoch = 3000
learning_rate = 0.03
errors = []
w1 = np.random.uniform(low=-1.0, high=1.0)
w2 = np.random.uniform(low=-1.0, high=1.0)

b = np.random.uniform(low=-1.0, high=1.0)

for epoch in range(num_epoch):
    
    y_hat = sigmoid(w1 * x1_data + w2*x2_data+ b)

    error = (-y_data * np.log(y_hat) - (1 - y_data) * np.log(1 - y_hat)).mean()
    if error < 0.00001:
        break

    w1 = w1 - learning_rate * ((y_hat - y_data) * x1_data).mean()
    w2 = w2 - learning_rate * ((y_hat - y_data) * x2_data).mean()
    b = b - learning_rate * (y_hat - y_data).mean()
    
    errors.append(error)
    
    if epoch % 5 == 0:
        print("{0:2} w1 = {1:.5f},b = {2:.5f}, error = {3:.5f}".format(epoch, w1, b, error))
# Out:
#  0 w1 = 0.47379,b = -0.13917, error = 0.59640
#  5 w1 = 0.50434,b = -0.13432, error = 0.58286
# 10 w1 = 0.53426,b = -0.12965, error = 0.56987
# 15 w1 = 0.56356,b = -0.12517, error = 0.55741
# 20 w1 = 0.59225,b = -0.12085, error = 0.54546
# 25 w1 = 0.62036,b = -0.11671, error = 0.53398
# 30 w1 = 0.64790,b = -0.11272, error = 0.52295
# 35 w1 = 0.67489,b = -0.10889, error = 0.51236
# 40 w1 = 0.70134,b = -0.10521, error = 0.50218
# 45 w1 = 0.72727,b = -0.10167, error = 0.49239
# 50 w1 = 0.75270,b = -0.09827, error = 0.48298
# 55 w1 = 0.77764,b = -0.09501, error = 0.47392
# 60 w1 = 0.80210,b = -0.09187, error = 0.46520
# 65 w1 = 0.82610,b = -0.08885, error = 0.45680
# 70 w1 = 0.84966,b = -0.08595, error = 0.44870
# 75 w1 = 0.87279,b = -0.08316, error = 0.44090
# 80 w1 = 0.89550,b = -0.08047, error = 0.43338
# 85 w1 = 0.91780,b = -0.07789, error = 0.42612
# 90 w1 = 0.93970,b = -0.07541, error = 0.41911
# 95 w1 = 0.96122,b = -0.07302, error = 0.41234
# ...

# %%
plt.plot(errors)

# %%
x_test=np.array([-0.5,0.0])
test_result = sigmoid(w1 * x_test[0] + w2*x_test[1]+ b)
print(test_result)

if test_result <0.5:
    test_class=0
elif test_result >=0.5:
    test_class=1
    
print(test_class)
# Out:
# 0.1271602486656571
# 0

# %%
tmpX = np.arange(-1, 1, 0.1)
tmpY = (-b + -w1*tmpX)/w2
#h=w1 * x1_data + w2*x2_data+ b
plt.plot(x1_data[0:half_m], x2_data[0:half_m], 'r.',label = '1')
plt.plot(x1_data[half_m:], x2_data[half_m:], 'b.',label = '0')
plt.plot(tmpX, tmpY,color='y')
plt.legend()
plt.show()
